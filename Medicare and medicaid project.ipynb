# %%
import pandas as pd
# Out:
# C:\Users\drudi\Anaconda3\envs\learn-env\lib\site-packages\numpy\_distributor_init.py:32: UserWarning: loaded more than 1 DLL from .libs:
# C:\Users\drudi\Anaconda3\envs\learn-env\lib\site-packages\numpy\.libs\libopenblas.NOIJJG62EMASZI6NYURL6JBKM4EVBGM7.gfortran-win_amd64.dll
# C:\Users\drudi\Anaconda3\envs\learn-env\lib\site-packages\numpy\.libs\libopenblas.PYQHXLVVQ7VESDPUVUADXEVJOBGHJPAY.gfortran-win_amd64.dll
#   stacklevel=1)

# %%
traditional = pd.read_csv('Pain_Management.csv')
traditional.head()
# Out:
#    zip_code  min_medicare_pricing_for_new_patient  \
# 0       210                                38.248
# 1       211                                38.248
# 2       212                                38.248
# 3       213                                38.248
# 4       214                                38.248
#
#    max_medicare_pricing_for_new_patient  \
# 0                               171.272
# 1                               171.272
# 2                               171.272
# 3                               171.272
# 4                               171.272
#
#    mode_medicare_pricing_for_new_patient  min_copay_for_new_patient  \
# 0                                136.376                      9.562
# 1                                136.376                      9.562
# 2                                136.376                      9.562
# 3                                136.376                      9.562
# 4                                136.376                      9.562
#
# ...

# %%
traditional.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 42954 entries, 0 to 42953
# Data columns (total 15 columns):
#  #   Column                                                Non-Null Count  Dtype
# ---  ------                                                --------------  -----
#  0   zip_code                                              42954 non-null  int64
#  1   min_medicare_pricing_for_new_patient                  42954 non-null  float64
#  2   max_medicare_pricing_for_new_patient                  42954 non-null  float64
#  3   mode_medicare_pricing_for_new_patient                 42954 non-null  float64
#  4   min_copay_for_new_patient                             42954 non-null  float64
#  5   max_copay_for_new_patient                             42954 non-null  float64
#  6   mode_copay_for_new_patient                            42954 non-null  float64
#  7   most_utilized_procedure_code_for_new_patient          42954 non-null  int64
# ...

# %%
interventional = pd.read_csv('Interventional_Pain_Management.csv')
interventional.head()
# Out:
#    zip_code  min_medicare_pricing_for_new_patient  \
# 0       210                                38.248
# 1       211                                38.248
# 2       212                                38.248
# 3       213                                38.248
# 4       214                                38.248
#
#    max_medicare_pricing_for_new_patient  \
# 0                               171.272
# 1                               171.272
# 2                               171.272
# 3                               171.272
# 4                               171.272
#
#    mode_medicare_pricing_for_new_patient  min_copay_for_new_patient  \
# 0                                136.376                      9.562
# 1                                136.376                      9.562
# 2                                136.376                      9.562
# 3                                136.376                      9.562
# 4                                136.376                      9.562
#
# ...

# %%
interventional.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 42954 entries, 0 to 42953
# Data columns (total 15 columns):
#  #   Column                                                Non-Null Count  Dtype
# ---  ------                                                --------------  -----
#  0   zip_code                                              42954 non-null  int64
#  1   min_medicare_pricing_for_new_patient                  42954 non-null  float64
#  2   max_medicare_pricing_for_new_patient                  42954 non-null  float64
#  3   mode_medicare_pricing_for_new_patient                 42954 non-null  float64
#  4   min_copay_for_new_patient                             42954 non-null  float64
#  5   max_copay_for_new_patient                             42954 non-null  float64
#  6   mode_copay_for_new_patient                            42954 non-null  float64
#  7   most_utilized_procedure_code_for_new_patient          42954 non-null  int64
# ...

# %%
traditional.mode_copay_for_new_patient.value_counts(1)
# Out:
# 32.174    0.047609
# 32.504    0.043791
# 32.190    0.034618
# 32.042    0.028728
# 33.032    0.026656
#             ...
# 35.544    0.000512
# 33.436    0.000489
# 34.134    0.000396
# 34.138    0.000233
# 36.690    0.000116
# Name: mode_copay_for_new_patient, Length: 97, dtype: float64

# %%
interventional.mode_copay_for_new_patient.value_counts(1)
# Out:
# 32.174    0.047609
# 32.504    0.043791
# 32.190    0.034618
# 32.042    0.028728
# 33.032    0.026656
#             ...
# 35.544    0.000512
# 33.436    0.000489
# 34.134    0.000396
# 34.138    0.000233
# 36.690    0.000116
# Name: mode_copay_for_new_patient, Length: 97, dtype: float64

# %%
traditional.describe()
# Out:
#            zip_code  min_medicare_pricing_for_new_patient  \
# count  42954.000000                          42954.000000
# mean   49590.561694                             36.577822
# std    27974.729869                              2.478634
# min      210.000000                             33.432000
# 25%    26037.250000                             34.736000
# 50%    48812.500000                             35.720000
# 75%    73042.750000                             37.464000
# max    99950.000000                             46.256000
#
#        max_medicare_pricing_for_new_patient  \
# count                          42954.000000
# mean                             165.921357
# std                                9.528802
# min                              153.976000
# 25%                              159.960000
# 50%                              163.584000
# 75%                              169.360000
# max                              219.248000
#
# ...

# %%
interventional.describe()
# Out:
#            zip_code  min_medicare_pricing_for_new_patient  \
# count  42954.000000                          42954.000000
# mean   49590.561694                             36.577822
# std    27974.729869                              2.478634
# min      210.000000                             33.432000
# 25%    26037.250000                             34.736000
# 50%    48812.500000                             35.720000
# 75%    73042.750000                             37.464000
# max    99950.000000                             46.256000
#
#        max_medicare_pricing_for_new_patient  \
# count                          42954.000000
# mean                             165.921357
# std                                9.528802
# min                              153.976000
# 25%                              159.960000
# 50%                              163.584000
# 75%                              169.360000
# max                              219.248000
#
# ...

# %%
surgical = pd.read_csv('Surgical_Oncology.csv')
radiation = pd.read_csv('Radiation_Oncology.csv')

# %%
surgical.head()
# Out:
#    zip_code  min_medicare_pricing_for_new_patient  \
# 0       210                                38.248
# 1       211                                38.248
# 2       212                                38.248
# 3       213                                38.248
# 4       214                                38.248
#
#    max_medicare_pricing_for_new_patient  \
# 0                               171.272
# 1                               171.272
# 2                               171.272
# 3                               171.272
# 4                               171.272
#
#    mode_medicare_pricing_for_new_patient  min_copay_for_new_patient  \
# 0                                171.272                      9.562
# 1                                171.272                      9.562
# 2                                171.272                      9.562
# 3                                171.272                      9.562
# 4                                171.272                      9.562
#
# ...

# %%
radiation.head()
# Out:
#    zip_code  min_medicare_pricing_for_new_patient  \
# 0       210                                38.248
# 1       211                                38.248
# 2       212                                38.248
# 3       213                                38.248
# 4       214                                38.248
#
#    max_medicare_pricing_for_new_patient  \
# 0                               171.272
# 1                               171.272
# 2                               171.272
# 3                               171.272
# 4                               171.272
#
#    mode_medicare_pricing_for_new_patient  min_copay_for_new_patient  \
# 0                                171.272                      9.562
# 1                                171.272                      9.562
# 2                                171.272                      9.562
# 3                                171.272                      9.562
# 4                                171.272                      9.562
#
# ...

# %%
surgical.describe()
# Out:
#            zip_code  min_medicare_pricing_for_new_patient  \
# count  42954.000000                          42954.000000
# mean   49590.561694                             36.577822
# std    27974.729869                              2.478634
# min      210.000000                             33.432000
# 25%    26037.250000                             34.736000
# 50%    48812.500000                             35.720000
# 75%    73042.750000                             37.464000
# max    99950.000000                             46.256000
#
#        max_medicare_pricing_for_new_patient  \
# count                          42954.000000
# mean                             165.921357
# std                                9.528802
# min                              153.976000
# 25%                              159.960000
# 50%                              163.584000
# 75%                              169.360000
# max                              219.248000
#
# ...

# %%
df = pd.read_csv('Skilled_Nursing_Facility_Quality.csv')

# %%
df.head()
# Out:
#   CMS Certification Number (CCN)                      Measure Code     Score  \
# 0                         NATION                S_001_03_NATL_RATE     99.10
# 1                         NATION  S_004_01_PPR_PD_NAT_UNADJUST_AVG      7.67
# 2                         NATION      S_004_01_PPR_PD_N_BETTER_NAT     13.00
# 3                         NATION     S_004_01_PPR_PD_N_NO_DIFF_NAT  15415.00
# 4                         NATION       S_004_01_PPR_PD_N_TOO_SMALL   1482.00
#
#    Footnote  Start Date    End Date
# 0       NaN  01/01/2019  12/31/2019
# 1       NaN  10/01/2017  09/30/2019
# 2       NaN  10/01/2017  09/30/2019
# 3       NaN  10/01/2017  09/30/2019
# 4       NaN  10/01/2017  09/30/2019
